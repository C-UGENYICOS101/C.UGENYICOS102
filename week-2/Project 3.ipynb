# %%
import pandas as pd
g_name= ["Evelyn","Jessica","Somto","Edith","Liza","Madonna","Waje","Tola","Aisha","Latifa"]
g_age= ["17","16","17","18","16","18","17","20","19","17"]
g_height= ["5.5","6.0","5.4","5.9","5.6","5.5","6.1","6.0","5.7","5.5"]
g_score= ["80","85","70","60","76","66","87","95","50","49"]

b_name= ["Chinedu","Liam","Wale","Gbenga","Abiola","Kola","Kunle","George","Thomas","Wesley"]
b_age= ["19","16","18","17","20","19","16","18","17","19"]
b_height= ["5.7","5.9","5.8","6.1","5.9","5.5","6.1","5.4","5.8","5.7"]
b_score= ["74","87","75","68","66","78","87","98","54","60"]

names= g_name + b_name
age= g_age + b_age
height = g_height + b_height
score = g_score + b_score
gender= ["female"] *10 + ["Male"]*10

table={
    "Names":names,
    "Age": age,
    "Height": height,
    "Score": score,
    "Gender": gender,
}
df= pd.DataFrame(table)
print(df)

# %%
Begin
Import pandas library
Input girls naame
Input girls Age
Input girls Height
Input Girls Score
Input Boys Name
Input Boys Age
Input Boys Height
Input Boys Score
COMBINE girls names and boys names INTO names
COMBINE girls age and boys age INTO ages
COMBINE girls height and boys height INTO heights
COMBINE girls scores and boys scores INTO scores
CREATE a table structure called table
STORE the table in a DataFrame called df
DISPLAY df
END
