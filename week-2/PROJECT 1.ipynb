# %%
```python
    PSEUDOCODE
BEGIN
      SET Total = 0
      FOR EACH item in basket:
	INPUT ItemPrice
	Total = Total +ItemPrice
      ENDFOR
      OUTPUT Total
      INPUT AmountPaid
      IF AmountPaid >= Total THEN
Change = AmountPaid – Total
OUTPUT “Transaction Complete.
Change: “, Change
      ELSE
OUTPUT “Insufficient Funds”
      ENDIF
END

```


```python
# 1. Taking Inputs
name1 = input("Enter first name: ")
age1 = int(input(f"Enter age for {name1}: "))

name2 = input("Enter second name: ")
age2 = int(input(f"Enter age for {name2}: "))

print(f"\nBefore Swap: {name1} is {age1}, {name2} is {age2}")

# 2. The Swap Algorithm using a Temporary Variable
temp = age1
age1 = age2
age2 = temp

# 3. Output the result
print(f"After Swap:  {name1} is {age1}, {name2} is {age2}")
```


```python

```
